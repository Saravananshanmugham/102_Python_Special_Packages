# %%
# Import the package for mysql
import mysql.connector

# %%
# Connecting To the Database in Localhost
dbcon = mysql.connector.connect(user='root', password='K@090403$s',
                              host='localhost', database='pytables')
print("Database Connection Established")
# Out:
# Database Connection Established

# %%
# Cursor to the database
Cursor = dbcon.cursor()
print("Database Cursor Created Successfully")
# Out:
# Database Cursor Created Successfully

# %%
# Payroll Table - Large table to play around using conditions

TableCreateScript=(
    "create table payroll"
    "(employee_id varchar(20) not null primary key,"
    "First_name varchar(30),"
    "last_name varchar(30),"
    "Division varchar(30),"
    "Department varchar(30),"
    "Doj date,"
    "Working_hrs float,"
    "Hourly_rate float"
    ")"
)
Cursor.execute(TableCreateScript)
print("Table Created Successfully")
# Out:
# Table Created Successfully

# %%
# 3 Tables - Customer_Master, InvoiceHeader, InvoiceDetails - To Play around Using Joins

Table_CustomerMaster = (
    "Create table CustomerMaster"
    "(CustomerID varchar(20) Not Null Primary Key,"
    "CustomerName varchar(50),"
    "Address varchar(50),"
    "Country varchar(20),"
    "City varchar(20),"
    "State varchar(10),"
    "Zip varchar(20))"
)
Cursor.execute(Table_CustomerMaster)
print("Table Created Successfully")
# Out:
# Table Created Successfully

# %%
# 3 Tables - Customer_Master, InvoiceHeader, InvoiceDetails - To Play around Using Joins

Table_InvoiceHeader = (
    "Create table InvoiceHeader"
    "(InvoiceNumber varchar(20) Not Null Primary Key,"
    "InvoiceDate date,"
    "CustomerID varchar(20))"
)
Cursor.execute(Table_InvoiceHeader)
print("Table Created Successfully")
# Out:
# Table Created Successfully

# %%
Table_InvoiceDetails = (
    "Create table InvoiceDetails"
    "(InvoiceNumber varchar(20),"
    "Quantity int,"
    "UnitCost float,"
    "UnitPrice float)"
)

Cursor.execute(Table_InvoiceDetails)
print("Table Created Successfully")
# Out:
# Table Created Successfully

# %%
# Common query for the insert record 
sql_payroll="Insert into payroll (Employee_ID,First_Name,Last_Name,Division,Department,DOJ,Working_hrs,Hourly_rate) values (%s,%s,%s,%s,%s,%s,%s,%s)"

# %%
# Insert of multiple records to the table
val=[
    ('GW29','Sara','Kling','Maine','Sales','1986-12-24',35.5,12.5),
    ('GBW09','Sean','Willis','Connecticut','Sales','1985-7-5',35.5,13.3),
    ('CW58','Colleen','Abel','New Hampshire','Sales','1990-7-26',42,16.75),
    ('AW55','Teri','Binga','Vermont','Sales','1988-6-7',40,8.75),
    ('GBC07','Frank','Culbert','Connecticut','Development','1983-6-12',40,12.6),
    ('GBS45','Kristen','DeVinney','Connecticut','Staff','1987-6-5',35,24),
    ('CW19','Theresa','Califano','New Hampshire','Sales','1989-2-26',35,12.1),
    ('GC04','Barry','Bally','Maine','Development','1983-4-15',40,21.5),
    ('CA26','Cheryl','Halal','New Hampshire','Research','1990-2-1',35.5,13.3),
    ('GC25','Harry','Swayne','Maine','Development','1990-12-30',40,21.5),
    ('GBC05','Shing','Chen','Connecticut','Development','1984-8-8',35.5,13.3),
    ('CC76','Seth','Rose','New Hampshire','Development','1990-4-5',32,5.5),
    ('GW14','Bob','Ambrose','Maine','Sales','1985-1-25',35.5,12.5),
    ('GBS59','Chris','Hume','Connecticut','Staff','1988-5-12',40,7.22),
    ('GBW47','Robert','Murray','Connecticut','Sales','1987-6-10',40,12.6),
    ('GBC11','James','Rich','Connecticut','Development','1986-10-11',35.5,13.3),
    ('CA18','George','Gorski','New Hampshire','Research','1985-5-7',40,22),
    ('GBS57','Paul','Hoffman','Connecticut','Staff','1987-12-19',40,22),
    ('AC49','Dean','Kramer','Vermont','Development','1987-6-23',40,15),
    ('GW18','Carol','Hill','Maine','Sales','1986-7-21',35.5,12.5),
    ('GBA19','Julia','Smith','Connecticut','Research','1984-2-17',25,8.52),
    ('AS03','Jacqueline','Banks','Vermont','Staff','1984-2-2',40,8.75),
    ('GW04','Jeffrey','Strong','Maine','Sales','1981-3-8',40,19.5),
    ('AW07','Jeri Lynn','MacFall','Vermont','Sales','1984-4-8',40,21.5),
    ('GA49','Sung','Kim','Maine','Research','1989-11-15',40,15.5),
    ('CA80','Theodore','Ness','New Hampshire','Research','1991-8-4',32,5.5),
    ('GW15','Brad','Hinkelman','Maine','Sales','1985-11-8',40,19.5),
    ('GBC08','Robert','Cuffaro','Connecticut','Development','1983-9-18',40,12.6),
    ('CS15','Donald','Reese','New Hampshire','Staff','1984-8-17',32,5.5),
    ('AW09','Joanne','Parker','Vermont','Sales','1984-8-23',40,21.5),
    ('GBA34','Susan','Drake','Connecticut','Research','1989-12-13',25,8.52),
    ('GBC29','James','Abel','Connecticut','Development','1991-2-5',35,12.1),
    ('GBW77','Laura','Reagan','Connecticut','Sales','1990-8-12',35,24),
    ('GS40','Brian','Smith','Maine','Staff','1988-11-5',40,19.5),
    ('GW32','Mary','Barber','Maine','Sales','1987-11-25',35.5,12.5),
    ('AW24','Peter','Allen','Vermont','Sales','1986-5-31',40,8.75),
    ('GC12','Mary','Altman','Maine','Development','1987-9-9',29.5,6.5),
    ('CA06','Fred','Mallory','New Hampshire','Research','1983-6-17',38,15.5),
    ('GBC65','Molly','Steadman','Connecticut','Development','1989-8-15',40,22),
    ('GBC49','Greg','Connors','Connecticut','Development','1987-11-4',38,15.5),
    ('GBA29','Kathy','Mayron','Connecticut','Research','1986-5-19',40,8.22),
    ('GS07','Bill','Simpson','Maine','Staff','1982-1-12',40,19.5),
    ('GBA28','Michael','Richardson','Connecticut','Research','1986-3-23',35,24),
    ('AA35','Melanie','Bowers','Vermont','Research','1986-12-5',15.5,6.5),
    ('GBS16','Kyle','EarnhSales','Connecticut','Staff','1984-10-8',40,22),
    ('GBC64','Lance','Davies','Connecticut','Development','1988-12-30',32,5.5),
    ('CC23','Anne','Davidson','New Hampshire','Development','1986-4-6',25,8.52),
    ('CA40','Doug','Briscoll','New Hampshire','Research','1987-5-26',38,15.5),
    ('GW37','George','Feldsott','Maine','Sales','1987-12-3',35.5,12.5),
    ('AS29','Steve','Singer','Vermont','Staff','1986-10-5',40,21.5),
    ('GBA14','Carol','Tucker','Connecticut','Research','1984-4-12',38,15.5),
    ('GC20','Henry','Paterson','Maine','Development','1987-10-28',40,21.5),
    ('GBA21','Brooks','Hillen','Connecticut','Research','1986-1-15',35,24),
    ('GBC09','Dominick','Mazza','Connecticut','Development','1986-10-10',40,21.5),
    ('CW30','Jennifer','Snyder','New Hampshire','Sales','1988-6-7',25,8.52),
    ('AW69','Joshua','Maccaluso','Vermont','Sales','1991-1-23',40,21.5),
    ('GBW05','Bill','Wheeler','Connecticut','Sales','1981-8-14',38,15.5),
    ('GBS69','Todd','Masters','Connecticut','Staff','1989-11-23',40,12.6),
    ('GW30','Karina','Abel','Maine','Sales','1987-1-12',42,16.75),
    ('AC27','Edward','Trelly','Vermont','Development','1986-6-17',40,8.75),
    ('GBA24','Christina','Lillie','Connecticut','Research','1987-5-29',25,8.52),
    ('AW58','Michael','Lewis','Vermont','Sales','1989-4-27',15.5,6.5),
    ('GA08','Jerry','McDonald','Maine','Research','1982-7-7',40,15.5),
    ('AC17','Lynne','Simmons','Vermont','Development','1988-11-23',35,12.1),
    ('AA25','Lindsey','Winger','Vermont','Research','1986-2-1',35,24),
    ('CW03','Chris','Reed','New Hampshire','Sales','1984-3-27',35.5,13.3),
    ('GA23','Paula','Robinson','Maine','Research','1987-12-7',29.5,6.5),
    ('GBW66','William','Abel','Connecticut','Sales','1989-10-14',40,15.5),
    ('CC45','Shirley','Dandrow','New Hampshire','Development','1991-3-14',35,12.1),
    ('GS54','Kim','Smith','Maine','Staff','1989-11-27',42,24),
    ('GC26','Maria','Switzer','Maine','Development','1991-6-3',29.5,13.3),
    ('GA27','John','Jacobs','Maine','Research','1986-10-4',40,6.5),
    ('GBW12','Bradley','Howard','Connecticut','Sales','1984-2-14',40,7.22),
    ('AA02','Frieda','Binga','Vermont','Research','1982-2-17',40,12.1),
    ('GC07','Holly','Taylor','Maine','Development','1984-8-17',29.5,16.75),
    ('GW47','Tim','BSaleshoff','Maine','Sales','1989-10-27',40,6.5),
    ('AW39','Esther','Williams','Vermont','Sales','1986-12-13',40,19.5),
    ('CS79','Theresa','Miller','New Hampshire','Staff','1991-3-4',40,22),
    ('AS23','Marianne','Calvin','Vermont','Staff','1985-7-23',40,15),
    ('GW11','Sue','Petty','Maine','Sales','1994-11-30',40,6.5),
    ('AS12','Grace','Sloan','Vermont','Staff','1984-11-2',40,15.5),
    ('GC24','Richard','Gibbs','Maine','Development','1989-1-23',29.5,15),
    ('AW04','Lorrie','Sullivan','Vermont','Sales','1981-3-3',15.5,12.6),
    ('GBA33','Ted','Hayes','Connecticut','Research','1986-12-7',32,8.75),
    ('GA57','Helen','StewSales','Maine','Research','1990-5-3',42,15.5),
    ('CS32','Katie','Smith','New Hampshire','Staff','1986-10-5',40,15),
    ('GBA23','Jane','Winters','Connecticut','Research','1989-11-7',35,12.6),
    ('GC02','Paul','MSalesin','Maine','Development','1979-4-19',40,6.5),
    ('GBA48','Geoff','Brown','Connecticut','Research','1987-7-1',40,6.5),
    ('AW48','Alice','Owens','Vermont','Sales','1987-3-2',15.5,5.5),
    ('AC53','Greg','Thomas','Vermont','Development','1987-12-24',40,16.75),
    ('GS09','Sam','Whitney','Maine','Staff','1983-11-28',40,7.22),
    ('AA70','Erin','Binga','Vermont','Research','1991-4-8',40,12.1),
    ('AW59','Amy','Tooley','Vermont','Sales','1990-9-1',15.5,6.5)
   ]
Cursor.executemany(sql_payroll, val)
dbcon.commit()
print(Cursor.rowcount, "Records inserted")
# Out:
# 94 Records inserted

# %%
myquery="select * from payroll limit 10"
Cursor.execute(myquery)
myresult = Cursor.fetchall()
for x in myresult:
    print(x)
# Out:
# ('AA02', 'Frieda', 'Binga', 'Vermont', 'Research', datetime.date(1982, 2, 17), 40.0, 12.1)
# ('AA25', 'Lindsey', 'Winger', 'Vermont', 'Research', datetime.date(1986, 2, 1), 35.0, 24.0)
# ('AA35', 'Melanie', 'Bowers', 'Vermont', 'Research', datetime.date(1986, 12, 5), 15.5, 6.5)
# ('AA70', 'Erin', 'Binga', 'Vermont', 'Research', datetime.date(1991, 4, 8), 40.0, 12.1)
# ('AC17', 'Lynne', 'Simmons', 'Vermont', 'Development', datetime.date(1988, 11, 23), 35.0, 12.1)
# ('AC27', 'Edward', 'Trelly', 'Vermont', 'Development', datetime.date(1986, 6, 17), 40.0, 8.75)
# ('AC49', 'Dean', 'Kramer', 'Vermont', 'Development', datetime.date(1987, 6, 23), 40.0, 15.0)
# ('AC53', 'Greg', 'Thomas', 'Vermont', 'Development', datetime.date(1987, 12, 24), 40.0, 16.75)
# ('AS03', 'Jacqueline', 'Banks', 'Vermont', 'Staff', datetime.date(1984, 2, 2), 40.0, 8.75)
# ('AS12', 'Grace', 'Sloan', 'Vermont', 'Staff', datetime.date(1984, 11, 2), 40.0, 15.5)

# %%
sql_CustomerMaster="Insert into CustomerMaster (CustomerID,CustomerName,Address,Country,City,State,Zip) values (%s,%s,%s,%s,%s,%s,%s)"

# %%
# Insert of multiple records to the table
val=[
    ('DOLLISCO0001','Dollis Cove Resort','765 Kingway','Canada','Charlottetown','PEI','C1A 1W3'),
    ('GETAWAYI0001','Getaway Inn','234 E Cannon Ave.','USA','Saginaw','MI','48605'),
    ('HOMEFURN0001','Home Furnishings Limited','234 Heritage Ave.','USA','Midland','MI','48640-9392'),
    ('JOHNSONK0001','Johnson, Kimberly','5678 S. 42nd Ave.','USA','Rockford','IL','61125-6149'),
    ('KELLYCON0001','Kelly Consulting','123 Yeo','Australia','Melbourne','VIC','3000'),
    ('KENSINGT0001','Kensington Gardens Resort','12345 Redmond Rd','USA','Milwaukee','WI','53204-9900'),
    ('HAMPTONV0001','Hampton Village Eatery','234 Hampton Village','USA','Springfield','IL','62703-1252'),
    ('HEALTHYC0001','Healthy Concepts','1234 Westown Road','USA','West Des Moines','IA','50625-4424'),
    ('LECLERC0001','LeClerc & Associates','4321 West Broadway','Canada','Montreal','PQ','H4Q 6J8'),
    ('LEISURET0001','Leisure & Travel Consultants','City 123','Australia','Sydney','NSW','2000'),
    ('LONDONBE0001','Londonberry Nursing Home','987 Portar Street','New Zealand','Auckland','',''),
    ('INTERNAT0001','International Mailing Corp.','8765 58th Street West','USA','St. Louis','MO','63156-5902'),
    ('ISNINDUS0001','ISN Industries','987 Union Circle','USA','Lockport','IL','60441-2239'),
    ('MANCHEST0001','Manchester Suites','678 W Orange Ave','USA','Lafayette','IN','47905-5855'),
    ('BLUEYOND0001','Blue Yonder Airlines','P.O. Box 1234','USA','Wichita','KS','67201'),
    ('COHOWINE0001','Coho Wintery','234 Hickman St.','USA','Springfield','IL','62703'),
    ('LASERMES0001','Laser Messenger Service','98765 Crossway Park Dr','USA','Bloomington','MN','55304-9840'),
    ('LAWRENCE0001','Lawrence Telemarketing','12345 21st Ave S','USA','Lawrence','KS','66208'),
    ('MIDCITYH0001','Mid-City Hospital','9876 N. Pioneer Road','USA','Gary','IN','46401-4211'),
    ('MIDLANDC0001','Midland Construction','5678 Fraser Ave N.','USA','Mishawaka','IN','46544'),
    ('MULTITEC0001','Multitech Office Components','1234 Sunlight Place','USA','Iowa City','IA','52230-1233'),
    ('MAGNIFIC0001','Magnificent Office Images','987 45 Ave.','Canada','Winnipeg','MB','R2S 3S7'),
    ('MAHLERST0001','Mahler State University','4321 McDaniels Rd','USA','Minneapolis','MN','55404-4000'),
    ('NETWORKS0001','Network Solutions','PO Box 2345','USA','Lake Zurich','IL','60047-1115'),
    ('NORTHCOL0001','North College','Business Office','USA','Fort Wayne','IN','46802-3313'),
    ('NORTHERN0001','Northern State College','234 Lee Ridge Road','USA','Chicago','IL','60604-2670'),
    ('MENDOTAU0001','Mendota University','8765 College Drive','USA','Grand Rapids','MI','49548-3343'),
    ('METROPOL0001','Metropolitan Fiber Systems','5678 W. Jackson Ave','USA','Milwaukee','WI','53202-5713'),
    ('NOVASCOT0001','Novia Scotia Tech. Institute','543 Abbot Ave.','Canada','Halifax','NS','B5P 7D7'),
    ('NOVASYST0001','Nova Systems, Inc.','123 W. Nichols Rd','USA','St. Paul','MN','55104'),
    ('OCTAGONM0001','Octagon Marketing Org.','1234 Redwood Trail','USA','Indianapolis','IN','46206-1099'),
    ('HUMONGOU0001','Humongous Insurance','4567 145th St NW','USA','Omaha','NE','68107-4509'),
    ('NATIONAL0001','National Shopping World','123 Apple Grove Square','USA','Indianapolis','IN','46205-2393'),
    ('PLACEMAD0001','Place & MacDero Associates','9876 Willingdon','Canada','Calgary','AB','T2P 4B9'),
    ('PLACEONE0001','Place One Suites','4567 East River Road','Canada','Vancouver','BC','V6C 3J9'),
    ('PLAZAONE0001','Plaza One','2345 42 St. W','USA','Woodbury','MN','55119'),
    ('NORTHERN0002','Northern Family Hospital','987 Royal Park Centre','Canada','St. Johns','NF','A1C 1K4'),
    ('NORTHSTA0001','Northstar Mall','5432 Principal Ave.','USA','Mankato','MN','56001'),
    ('RAINBOWR0001','Rainbow Research','3456 N. Jupiter St','USA','St Louis','MO','63156-3427'),
    ('REDSFOOD0001','Reds Food Market','8765 W. Cordoba Way','USA','Kansas City','MO','64108-1862'),
    ('MARGIEST0001','Margies Travel','6789 82 Ave S.','USA','Minneapolis','MN','55402-1249'),
    ('OFFICEDE0001','Office Design Systems Ltd','Place 123 Suite 3','Canada','Winnipeg','MB','R3M 2G6'),
    ('PACIFICD0001','Pacific Digital','76543 Commerical Street','USA','Independence','MO','64501'),
    ('RIVERSID0001','Riverside University','5678 Herman St.','Canada','Vancouver','BC','V6E 3J7'),
    ('ROSELLEN0001','Rosellen General Hospital','8765 Barclay St.','Canada','Regina','SK','S7K 5C7'),
    ('SINCLAIR0001','Sinclair State University','SSU Box 123','USA','Arlington Heights','IL','60004-6122'),
    ('POLKVALL0001','Polk Valley Highway Dept.','Rural Route 123 Box 45G','USA','McHenry','IL','60050'),
    ('PULASKIE0001','Pulaski Enterprises Inc.','3456 E. Main Parkway','USA','Duluth','MN','55806'),
    ('STMARYHO0001','St. Marys Hospital','2345 N. River Dr.','USA','Milwaukee','WI','53203-2323'),
    ('STPATRIC0001','St. Patricks Hospital','234 Phillip','Australia','Melbourne','VIC','3000'),
    ('SUPERFOO0001','Super Foods Plus','6543 N.E. Pusher Rd.','USA','Detroit','MI','48233-1232'),
    ('REYNOLDS0001','Reynolds State College','456 College Drive','USA','Benton Harbor','MI','49022-9090'),
    ('DOWNTOWN001','Downtown Hotel','987 Chestnut Avenue','','Chicago','IL','60618-2991'),
    ('VISIONIN0001','Vision Inc.','123 S.W. 49 Ave','USA','Indianapolis','IN','46206-1222'),
    ('VISTATRA0001','Vista Travel','5678 Broadway','Canada','Saskatoon','SK','S5S 6W9'),
    ('WESTCENT0001','West Central Distributors','1234 2nd Street','USA','Rockford','IL','61126-3214'),
    ('SNELLING0001','Snelling Communications Inc.','4321 East Wisconsin Ave.','USA','Chicago','IL','60604-4100'),
    ('SSPROPER0001','S & S Properties','1234 S. Roberts St.','USA','Detroit','MI','48233-2190'),
    ('WESTSIDE0001','Westside Cable Service','123 Domino St. N','USA','Lansing','MI','48924-9237'),
    ('WORLDENT0001','World Enterprises','987 Office Plaza Drive','USA','Detroit','MI','48233-4832'),
    ('GREENWAY0001','Greenway Foods','87654 N 19th Avenue','USA','Chicago','IL','60601-6363'),
    ('UNIFIEDW0001','Unified Wire and Cable Systems','123 N. Meriam Ave','USA','Grand Rapids','MI','49548'),
    ('VANCOUVE0001','Vancouver Resort Hotels','432 12 Ave. North','Canada','Vancouver','BC','V6E 3J7'),
    ('COUNTRYV0001','Country View Estates','123 Albert Ave','New Zealand','Palmerston North','',''),
    ('CRAWFORD0001','Crawfords, Inc.','321 Park Drive','USA','Columbia','MO','65201-3322'),
    ('HEARTLAN0001','Heartland Tower Systems','9876 Stevens Street','USA','Kansas City','MO','64108'),
    ('HOLLINGC0001','Holling Communications Inc.','123 Sugar Grove','USA','Columbia','MO','65201-3846'),
    ('ADVANCED0001','Advanced Paper Co.','456 19th Street S.','USA','Chicago','IL','60603-911'),
    ('ADVANCED0002','Advanced Tech Satellite System','8765 66 Ave.','Canada','Toronto','ON','M8D 7R5'),
    ('ALTONMAN0001','Alton Manufacturing','P.O. Box 3343','USA','Detroit','MI','48233-3343'),
    ('EXECUTIV0001','Executive Resources','123 Alfred St','Australia','Sydney','NSW','2000'),
    ('FRANCHIS0001','Franchise Office Machines','456 Sherwood Park South','USA','Arlington Heights','IL','6004-2922'),
    ('ASSOCIAT0001','Associated Insurance Company','321 Garden Mall','USA','Lincoln','NE','68502-3090'),
    ('ASTORSUI0001','Astor Suites','987 West Alaska Ave','USA','Gary','IN','46401-3455'),
    ('ATMORERE0001','Atmore Retirement Center','567 W 7th St.','USA','Bloomington','IL','61701-9392'),
    ('AARONFIT0001','Aaron Fitz Electrical','One Microsoft Way','USA','Redmond','WA','98052-6399'),
    ('ADAMPARK0001','Adam Park Resort','Suite 9876','USA','Indianapolis','IN','46206-1391'),
    ('BERRYMED0001','Berry Medical Center','Suite 123','USA','Fond Du Lac','WI','54935-9990'),
    ('BOYLESCO0001','Boyles Country Inns','1234 Burke','Australia','Melbourne','VIC','3000'),
    ('BREAKTHR0001','Breakthrough Telemarketing','3456 Arbutus St.','Canada','Montreal','PQ','H3R 3T2'),
    ('AMERICAN0001','American Science Museum','789 North Carlton Place','USA','St. Louis','MO','63115'),
    ('AMERICAN0002','American Electrical Contractor','3456 North Calumet Avenue','USA','Iowa City','IA','52240-1827'),
    ('CELLULAR0001','Cellular Express','5678 Horseshoe Way','USA','Aurora','IL','60507-3322'),
    ('CENTERSU0001','Center Suite Hotel','8765 51 Ave S','USA','Minneapolis','MN','55401-7694'),
    ('CENTRALC0001','Central Communications LTD','2345 Aukland St. West','USA','Chicago','IL','60601-2333'),
    ('BAKERSEM0001','Bakers Emporium Inc.','789 University Ave','USA','Fort Wayne','IN','46802-3918'),
    ('FOURTHCO0001','Fourth Coffee','345 Industrial Drive','USA','Beatrice','NE','68350-1010'),
    ('COMMUNIC0001','Communication Connections','Place 123, Suite 3','Canada','Winnipeg','MB','R3M 2G6'),
    ('COMMUNIC0002','Communication Connections','765 Curtis','Canada','Vancouver','BC','V6C 3J9'),
    ('COMPUTEC0001','Compu-Tech Solutions','23456 Meridan St. N.E.','USA','Green Bay','WI','54305-5303'),
    ('CONTOSOL0001','Contoso, Ltd.','456 Mineral Point Road','USA','Omaha','NE','68145-2401'),
    ('CASTLEIN0001','Castle Inn Resort','234 103 Ave.','Canada','Ottawa','ON','K4T 8W2'),
    ('COMPUTER0003','Computer Equipment Leasing','123 Churchill Rd','Australia','Sydney','NSW','2000'),
    ('COMTELPA0001','Comtel-Page Inc.','23456 82 Ave.','USA','Ames','IA','50010-3976'),
    ('CONTINEN0001','Continental Properties','678 Falcon','Australia','Sydney','NSW','2000'),
    ('CENTRALD0001','Central Distributing','Suite 13','USA','La Crosse','WI','54601-9975'),
    ('CENTRALI0001','Central Illinois Hospital','765 West 24th Street','USA','Peoria','IL','61601-4542'),
    ('DATACOMM0001','Data Communications Inc.','9876 112 St.','Canada','Edmonton','AB','T5P 1T1'),
    ('DIALDIRE0001','Dial Direct Paging Inc.','1234 SE Marine','USA','St. Louis','MO','63155-2343'),
    ('DIRECTMA0001','Direct Marketers','8765 9 St. W.','USA','St. Paul','MN','55101-8011'),
    ('COMPUTER0001','Computerized Phone Systems','456 17 St S','USA','Madison','WI','53701-6652'),
    ('COMPUTER0002','Computers Unlimited','9876 Bernard St.','Canada','Edmonton','AB','T5J 2G5')
]

Cursor.executemany(sql_CustomerMaster, val)
dbcon.commit()
print(Cursor.rowcount, "Records inserted")
# Out:
# 102 Records inserted

# %%
myquery="select * from customermaster limit 10"
Cursor.execute(myquery)
myresult = Cursor.fetchall()
for x in myresult:
    print(x)
# Out:
# ('AARONFIT0001', 'Aaron Fitz Electrical', 'One Microsoft Way', 'USA', 'Redmond', 'WA', '98052-6399')
# ('ADAMPARK0001', 'Adam Park Resort', 'Suite 9876', 'USA', 'Indianapolis', 'IN', '46206-1391')
# ('ADVANCED0001', 'Advanced Paper Co.', '456 19th Street S.', 'USA', 'Chicago', 'IL', '60603-911')
# ('ADVANCED0002', 'Advanced Tech Satellite System', '8765 66 Ave.', 'Canada', 'Toronto', 'ON', 'M8D 7R5')
# ('ALTONMAN0001', 'Alton Manufacturing', 'P.O. Box 3343', 'USA', 'Detroit', 'MI', '48233-3343')
# ('AMERICAN0001', 'American Science Museum', '789 North Carlton Place', 'USA', 'St. Louis', 'MO', '63115')
# ('AMERICAN0002', 'American Electrical Contractor', '3456 North Calumet Avenue', 'USA', 'Iowa City', 'IA', '52240-1827')
# ('ASSOCIAT0001', 'Associated Insurance Company', '321 Garden Mall', 'USA', 'Lincoln', 'NE', '68502-3090')
# ('ASTORSUI0001', 'Astor Suites', '987 West Alaska Ave', 'USA', 'Gary', 'IN', '46401-3455')
# ...

# %%
sql_InvoiceHeader="Insert into InvoiceHeader (InvoiceNumber,InvoiceDate,CustomerID) values (%s,%s,%s)"

# %%
# Insert of multiple records to the table
val=[
('ORDST1025','2005-5-8','BAKERSEM0001'),
('STDINV2251','2007-4-12','BAKERSEM0001'),
('ORDST1026','2005-5-8','AARONFIT0001'),
('STDINV2252','2007-4-12','AARONFIT0001'),
('ORD1002','2004-5-7','METROPOL0001'),
('INV1024','2004-2-10','AARONFIT0001'),
('INV1025','2004-2-15','AARONFIT0001'),
('ORDPH1005','2004-5-10','LECLERC0001'),
('ORD1000','2004-5-8','MAGNIFIC0001'),
('ORD1001','2004-5-10','HOLLINGC0001'),
('ORDST1008','2004-5-10','MAHLERST0001'),
('ORD1007','2004-5-10','ASTORSUI0001'),
('ORDPH1001','2004-5-4','CONTOSOL0001'),
('ORDST1016','2004-5-10','BAKERSEM0001'),
('ORDPH1006','2004-5-10','BOYLESCO0001'),
('ORDPH1007','2004-5-10','CONTOSOL0001'),
('STDINV2262000','2000-4-12','ADVANCED0002'),
('STDINV2265000','2000-4-12','COUNTRYV0001'),
('STDINV2264000','2000-4-12','ADVANCED0001'),
('STDINV2263000','2000-4-12','CENTRALD0001'),
('STDINV2263005','2005-4-12','CENTRALD0001'),
('STDINV2264005','2005-4-12','ADVANCED0001'),
('STDINV2265005','2005-4-12','COUNTRYV0001'),
('STDINV2264003','2003-4-12','ADVANCED0001'),
('STDINV2262003','2003-4-12','ADVANCED0002'),
('STDINV2262005','2005-4-12','ADVANCED0002'),
('STDINV2264001','2002-4-12','ADVANCED0001'),
('STDINV2265001','2002-4-12','COUNTRYV0001'),
('STDINV2265002','2003-4-12','COUNTRYV0001'),
('STDINV2265','2001-4-12','COUNTRYV0001'),
('STDINV2262001','2002-4-12','ADVANCED0002'),
('STDINV2263001','2002-4-12','CENTRALD0001'),
('STDINV2262','2001-4-12','ADVANCED0002'),
('STDINV2263','2001-4-12','CENTRALD0001'),
('STDINV2264','2001-4-12','ADVANCED0001'),
('STDINV2254','2007-4-12','BAKERSEM0001'),
('ORDST2223','2007-5-8','AMERICAN0001'),
('ORDST2230','2007-4-12',''),
('BKO1003','2005-5-8','AMERICAN0001'),
('STDINV2253','2007-4-12','AMERICAN0001'),
('INVPS1006','2004-5-10','CONTOSOL0001'),
('ORDST1024','2005-5-8','ADAMPARK0001'),
('STDINV2250','2007-4-12','ADAMPARK0001'),
('ORDSPEC1001','2004-5-19','COUNTRYV0001'),
('INVSP1004','2007-4-12','COUNTRYV0001'),
('INV1020','2004-5-10','ASTORSUI0001'),
('INVSP1003','2007-4-12','COMPUTER0001'),
('BKO1001','2004-5-10','CONTOSOL0001'),
('STDINV2249','2007-4-12','CONTOSOL0001'),
('ORD1004','2004-5-18','VISIONIN0001'),
('STDINV2248','2007-4-12','VISIONIN0001'),
('ORDSPEC1000','2004-5-26','COMPUTER0001'),
('STDINV2245','2007-4-12','METROPOL0001'),
('STDINV2246','2007-4-12','COMMUNIC0002'),
('STDINV2247','2007-4-12','COMMUNIC0001'),
('STDINV2240','2007-4-12','ASSOCIAT0001'),
('ORD1005','2004-5-29','COMMUNIC0002'),
('ORDST1013','2004-5-19','COMMUNIC0001'),
('INVPS1007','2007-4-12','WESTCENT0001'),
('STDINV2237','2007-4-12','OFFICEDE0001'),
('STDINV2241','2007-4-12','LAWRENCE0001'),
('ORDST1012','2004-5-27','WESTSIDE0001'),
('ORDST1014','2004-5-19','LASERMES0001'),
('ORDST1015','2004-5-28','METROPOL0001'),
('ORDRP1000','2004-5-24','ATMORERE0001'),
('ORDST1002','2004-4-28','ASSOCIAT0001'),
('ORDST1011','2004-5-20','LAWRENCE0001'),
('ORDPH1002','2004-5-17','WESTCENT0001'),
('ORDPH1003','2004-5-16','CENTRALI0001'),
('ORDPH1004','2004-5-22','MIDLANDC0001'),
('INVSP1001','2004-5-18','LONDONBE0001'),
('ORD1003','2004-5-7','OFFICEDE0001'),
('ORD1006','2004-5-16','KENSINGT0001'),
('INV1013','2004-5-27','ADVANCED0002'),
('INVSP1000','2004-5-20','PLAZAONE0001'),
('INVSP1002','2004-5-22','MIDLANDC0001'),
('INVPS1005','2004-5-10','BOYLESCO0001'),
('INV1011','2004-5-19','MENDOTAU0001'),
('INV1012','2004-5-27','KELLYCON0001'),
('INVPS1001','2004-5-25','HOLLINGC0001'),
('INVPS1002','2004-5-10','BREAKTHR0001'),
('INVPS1004','2004-5-10','LECLERC0001'),
('INV1010','2004-5-17','ISNINDUS0001'),
('INV1016','2004-5-10','METROPOL0001'),
('INV1022','2004-5-20','PLAZAONE0001'),
('ORDST1022','2004-7-7','CASTLEIN0001'),
('ORDST1023','2004-7-7','ADVANCED0002'),
('QTEST1017','2004-5-17','SINCLAIR0001'),
('STDINV2225','2007-4-12','ADAMPARK0001'),
('STDINV2226','2007-4-12','BAKERSEM0001'),
('STDINV2227','2007-4-12','AARONFIT0001'),
('ORDST1021','2004-7-8','LONDONBE0001'),
('ORDST1017','2004-5-22','LEISURET0001'),
('STDINV2234','2007-4-12','LEISURET0001'),
('ORDST1018','2004-7-8','COUNTRYV0001'),
('ORDST1019','2004-7-8','ADVANCED0002'),
('ORDST1020','2004-7-8','DOLLISCO0001'),
('ORD1009','2006-9-11','ADAMPARK0001'),
('STDINV2228','2007-4-12','AARONFIT0001'),
('STDINV2229','2007-4-12','ADAMPARK0001'),
('ORDST2222','2007-3-31','HOLLINGC0001'),
('STDINV2224','2007-3-31','HOLLINGC0001'),
('ORD1008','2006-9-11','AARONFIT0001'),
('STDINV2222','2007-3-30','AARONFIT0001'),
('ORDST2221','2007-3-31','BREAKTHR0001'),
('STDINV2223','2007-3-31','BREAKTHR0001'),
('ORDST2219','2007-3-29','PLAZAONE0001'),
('STDINV2221','2007-3-29','PLAZAONE0001'),
('ORDST2220','2007-3-30','AARONFIT0001'),
('STDINV2219','2007-3-27','AARONFIT0001'),
('ORDST2218','2007-3-28','AARONFIT0001'),
('STDINV2220','2007-3-28','AARONFIT0001'),
('ORDST2216','2007-3-26','VANCOUVE0001'),
('STDINV2218','2007-3-26','VANCOUVE0001'),
('ORDST2217','2007-3-27','AARONFIT0001'),
('STDINV2216','2007-3-24','ASTORSUI0001'),
('ORDST2215','2007-3-25','PLAZAONE0001'),
('STDINV2217','2007-3-25','PLAZAONE0001'),
('ORDST2213','2007-3-23','BLUEYOND0001'),
('STDINV2215','2007-3-23','BLUEYOND0001'),
('ORDST2214','2007-3-24','ASTORSUI0001'),
('STDINV2213','2007-3-21','MAHLERST0001'),
('ORDST2212','2007-3-22','LAWRENCE0001'),
('STDINV2214','2007-3-22','LAWRENCE0001'),
('ORDST2210','2007-3-20','HOLLINGC0001'),
('STDINV2212','2007-3-20','HOLLINGC0001'),
('ORDST2211','2007-3-21','MAHLERST0001'),
('STDINV2210','2007-3-18','HOLLINGC0001'),
('ORDST2209','2007-3-19','BREAKTHR0001'),
('STDINV2211','2007-3-19','BREAKTHR0001'),
('ORDST2207','2007-3-18','PLAZAONE0001'),
('STDINV2209','2007-3-18','PLAZAONE0001'),
('ORDST2208','2007-3-18','HOLLINGC0001'),
('STDINV2207','2007-3-17','METROPOL0001'),
('ORDST2206','2007-3-18','ASTORSUI0001'),
('STDINV2208','2007-3-18','ASTORSUI0001'),
('ORDST2204','2007-3-17','MAGNIFIC0001'),
('STDINV2206','2007-3-17','MAGNIFIC0001'),
('ORDST2205','2007-3-17','METROPOL0001'),
('STDINV2204','2007-3-15','PLAZAONE0001'),
('ORDST2203','2007-3-16','CENTRALC0001'),
('STDINV2205','2007-3-16','CENTRALC0001'),
('ORDST2201','2007-3-14','AARONFIT0001'),
('STDINV2203','2007-3-14','AARONFIT0001'),
('ORDST2202','2007-3-15','PLAZAONE0001'),
('STDINV2201','2007-3-13','VANCOUVE0001'),
('ORDST2200','2007-3-14','AARONFIT0001'),
('STDINV2202','2007-3-14','AARONFIT0001'),
('ORDST2198','2007-3-12','PLAZAONE0001'),
('STDINV2200','2007-3-12','PLAZAONE0001'),
('ORDST2199','2007-3-13','VANCOUVE0001'),
('STDINV2198','2007-3-11','BLUEYOND0001'),
('ORDST2197','2007-3-11','ASTORSUI0001'),
('STDINV2199','2007-3-11','ASTORSUI0001'),
('ORDST2195','2007-3-11','LAWRENCE0001'),
('STDINV2197','2007-3-11','LAWRENCE0001'),
('ORDST2196','2007-3-11','BLUEYOND0001'),
('STDINV2195','2007-3-9','ASTORSUI0001'),
('ORDST2194','2007-3-10','MAHLERST0001'),
('STDINV2196','2007-3-10','MAHLERST0001'),
('ORDST2192','2007-3-8','METROPOL0001'),
('STDINV2194','2007-3-8','METROPOL0001'),
('ORDST2193','2007-3-9','ASTORSUI0001'),
('STDINV2192','2007-3-6','CENTRALC0001'),
('ORDST2191','2007-3-7','MAGNIFIC0001'),
('STDINV2193','2007-3-7','MAGNIFIC0001'),
('ORDST2189','2007-3-5','PLAZAONE0001'),
('STDINV2191','2007-3-5','PLAZAONE0001'),
('ORDST2190','2007-3-6','CENTRALC0001'),
('STDINV2189','2007-3-4','AARONFIT0001'),
('ORDST2188','2007-3-4','AARONFIT0001'),
('STDINV2190','2007-3-4','AARONFIT0001'),
('ORDST2186','2007-3-4','VANCOUVE0001'),
('STDINV2188','2007-3-4','VANCOUVE0001'),
('ORDST2187','2007-3-4','AARONFIT0001'),
('STDINV2186','2007-3-3','ASTORSUI0001'),
('ORDST2185','2007-3-4','PLAZAONE0001'),
('STDINV2187','2007-3-4','PLAZAONE0001'),
('ORDST2183','2007-3-3','BLUEYOND0001'),
('STDINV2185','2007-3-3','BLUEYOND0001'),
('ORDST2184','2007-3-3','ASTORSUI0001'),
('STDINV2183','2006-3-2','MAHLERST0001'),
('ORDST2182','2006-3-2','LAWRENCE0001'),
('STDINV2184','2006-3-2','LAWRENCE0001'),
('ORDST2180','2006-3-1','METROPOL0001'),
('STDINV2182','2007-4-11','METROPOL0001'),
('ORDST2181','2006-3-2','MAHLERST0001'),
('STDINV2180','2006-2-28','CENTRALC0001'),
('ORDST2179','2006-2-28','MAGNIFIC0001'),
('STDINV2181','2006-2-28','MAGNIFIC0001'),
('ORDST2177','2006-2-27','PLAZAONE0001'),
('STDINV2179','2006-3-27','PLAZAONE0001'),
('ORDST2178','2006-2-28','CENTRALC0001'),
('STDINV2177','2006-2-25','CONTOSOL0001'),
('ORDST2176','2006-2-26','VANCOUVE0001'),
('STDINV2178','2006-2-26','VANCOUVE0001'),
('ORDST2174','2006-2-25','AARONFIT0001'),
('STDINV2176','2006-2-25','AARONFIT0001'),
('ORDST2175','2006-2-25','CONTOSOL0001'),
('STDINV2174','2006-2-23','BREAKTHR0001'),
('ORDST2173','2006-2-24','HOLLINGC0001'),
('STDINV2175','2006-2-24','HOLLINGC0001'),
('ORDST2171','2006-2-23','HOLLINGC0001'),
('STDINV2173','2006-2-23','HOLLINGC0001'),
('ORDST2172','2006-2-23','BREAKTHR0001'),
('STDINV2171','2006-2-22','ASTORSUI0001'),
('ORDST2170','2006-2-22','PLAZAONE0001'),
('STDINV2172','2006-2-22','PLAZAONE0001'),
('ORDST2168','2006-2-22','METROPOL0001'),
('STDINV2170','2006-2-22','METROPOL0001'),
('ORDST2169','2006-2-22','ASTORSUI0001'),
('STDINV2168','2006-2-20','CENTRALC0001'),
('ORDST2167','2006-2-21','MAGNIFIC0001'),
('STDINV2169','2006-2-21','MAGNIFIC0001'),
('ORDST2165','2006-2-20','PLAZAONE0001'),
('STDINV2167','2006-2-20','PLAZAONE0001'),
('ORDST2166','2006-2-20','CENTRALC0001'),
('STDINV2165','2006-2-18','VANCOUVE0001'),
('ORDST2164','2006-2-19','AARONFIT0001'),
('STDINV2166','2006-2-19','AARONFIT0001'),
('ORDST2162','2006-2-18','PLAZAONE0001'),
('STDINV2164','2006-2-18','PLAZAONE0001'),
('ORDST2163','2006-2-18','VANCOUVE0001'),
('STDINV2162','2006-2-17','BLUEYOND0001'),
('ORDST2161','2007-2-17','ASTORSUI0001'),
('STDINV2163','2007-2-17','ASTORSUI0001'),
('ORDST2159','2007-2-16','LAWRENCE0001'),
('STDINV2161','2007-2-16','LAWRENCE0001'),
('ORDST2160','2006-2-17','BLUEYOND0001'),
('STDINV2159','2007-2-16','METROPOL0001'),
('ORDST2158','2007-2-15','MAHLERST0001'),
('STDINV2160','2006-3-17','MAHLERST0001'),
('ORDST2156','2007-2-11','MAGNIFIC0001'),
('STDINV2158','2007-2-11','MAGNIFIC0001'),
('ORDST2157','2007-2-14','METROPOL0001'),
('STDINV2156','2007-2-9','PLAZAONE0001'),
('ORDST2155','2007-2-10','CENTRALC0001'),
('STDINV2157','2007-2-10','CENTRALC0001'),
('ORDST2153','2007-2-9','VANCOUVE0001'),
('STDINV2155','2007-2-9','VANCOUVE0001'),
('ORDST2154','2007-2-9','PLAZAONE0001'),
('STDINV2153','2007-2-5','PLAZAONE0001'),
('ORDST2152','2007-2-8','CONTOSOL0001'),
('STDINV2154','2007-2-8','CONTOSOL0001'),
('ORDST2150','2007-2-4','ASTORSUI0001'),
('STDINV2151','2007-2-4','ASTORSUI0001'),
('ORDST2151','2007-2-5','PLAZAONE0001'),
('STDINV2149','2007-2-3','LAWRENCE0001'),
('ORDST2149','2007-2-3','BLUEYOND0001'),
('STDINV2150','2007-2-3','BLUEYOND0001'),
('ORDST2147','2007-2-3','MAHLERST0001'),
('STDINV2148','2007-2-3','MAHLERST0001'),
('ORDST2148','2007-2-3','LAWRENCE0001'),
('STDINV2146','2007-1-30','PLAZAONE0001'),
('ORDST2146','2007-2-2','METROPOL0001'),
('STDINV2147','2007-2-2','METROPOL0001'),
('ORDST2144','2007-1-24','AARONFIT0001'),
('STDINV2145','2007-1-24','AARONFIT0001'),
('ORDST2145','2007-1-30','PLAZAONE0001'),
('STDINV2143','2007-1-22','VANCOUVE0001'),
('ORDST2143','2007-1-23','AARONFIT0001'),
('STDINV2144','2007-1-23','AARONFIT0001'),
('ORDST2141','2007-1-21','PLAZAONE0001'),
('STDINV2142','2007-1-21','PLAZAONE0001'),
('ORDST2142','2007-1-22','VANCOUVE0001'),
('STDINV2140','2007-1-18','BLUEYOND0001'),
('ORDST2140','2007-1-19','ASTORSUI0001'),
('STDINV2141','2007-1-19','ASTORSUI0001'),
('ORDST2138','2007-1-17','LAWRENCE0001'),
('STDINV2139','2007-1-17','LAWRENCE0001'),
('ORDST2139','2007-1-18','BLUEYOND0001'),
('STDINV2137','2007-1-15','METROPOL0001'),
('ORDST2137','2007-1-15','MAHLERST0001'),
('STDINV2138','2007-1-15','MAHLERST0001'),
('ORDST2135','2007-1-14','MAGNIFIC0001'),
('STDINV2136','2007-1-14','MAGNIFIC0001'),
('ORDST2136','2007-1-15','METROPOL0001'),
('STDINV2134','2007-1-12','PLAZAONE0001'),
('ORDST2134','2007-1-13','CENTRALC0001'),
('STDINV2135','2007-1-13','CENTRALC0001'),
('ORDST2132','2007-1-11','VANCOUVE0001'),
('STDINV2133','2007-1-11','VANCOUVE0001'),
('ORDST2133','2007-1-12','PLAZAONE0001'),
('STDINV2131','2007-1-8','AARONFIT0001'),
('ORDST2131','2007-1-10','CONTOSOL0001'),
('STDINV2132','2007-1-10','CONTOSOL0001'),
('ORDST2116','2006-3-31','HOLLINGC0001'),
('STDINV2117','2006-3-31','HOLLINGC0001'),
('ORDST2117','2007-1-1','CONTOSOL0001'),
('STDINV2115','2006-3-30','AARONFIT0001'),
('ORDST2115','2006-3-31','BREAKTHR0001'),
('STDINV2116','2006-3-31','BREAKTHR0001'),
('ORDST2113','2006-3-29','PLAZAONE0001'),
('STDINV2114','2006-3-29','PLAZAONE0001'),
('ORDST2114','2006-3-30','AARONFIT0001'),
('STDINV2112','2006-3-27','AARONFIT0001'),
('ORDST2112','2006-3-28','AARONFIT0001'),
('STDINV2113','2006-3-28','AARONFIT0001'),
('ORDST2110','2006-3-26','VANCOUVE0001'),
('STDINV2111','2006-3-26','VANCOUVE0001'),
('ORDST2111','2006-3-27','AARONFIT0001'),
('STDINV2109','2006-3-24','ASTORSUI0001'),
('ORDST2109','2006-3-25','PLAZAONE0001'),
('STDINV2110','2006-3-25','PLAZAONE0001'),
('ORDST2107','2006-3-23','BLUEYOND0001'),
('STDINV2108','2006-3-23','BLUEYOND0001'),
('ORDST2108','2006-3-24','ASTORSUI0001'),
('STDINV2106','2006-3-21','MAHLERST0001'),
('ORDST2106','2006-3-22','LAWRENCE0001'),
('STDINV2107','2006-3-22','LAWRENCE0001'),
('ORDST2104','2006-3-20','HOLLINGC0001'),
('STDINV2105','2006-3-20','HOLLINGC0001'),
('ORDST2105','2006-3-21','MAHLERST0001'),
('STDINV2103','2006-3-18','HOLLINGC0001'),
('ORDST2103','2006-3-19','BREAKTHR0001'),
('STDINV2104','2006-3-19','BREAKTHR0001'),
('ORDST2101','2006-3-18','PLAZAONE0001'),
('STDINV2102','2006-3-18','PLAZAONE0001'),
('ORDST2102','2006-3-18','HOLLINGC0001'),
('STDINV2100','2006-3-17','METROPOL0001'),
('ORDST2100','2006-3-18','ASTORSUI0001'),
('STDINV2101','2006-3-18','ASTORSUI0001'),
('ORDST2098','2006-3-17','MAGNIFIC0001'),
('STDINV2099','2006-3-17','MAGNIFIC0001'),
('ORDST2099','2006-3-17','METROPOL0001'),
('STDINV2097','2006-3-15','PLACEONE0001'),
('ORDST2097','2006-3-16','CENTRALC0001'),
('STDINV2098','2006-3-16','CENTRALC0001'),
('ORDST2095','2006-3-14','AARONFIT0001'),
('STDINV2096','2006-3-14','AARONFIT0001'),
('ORDST2096','2006-3-15','PLACEONE0001'),
('STDINV2094','2006-3-13','VANCOUVE0001'),
('ORDST2094','2006-3-14','AARONFIT0001'),
('STDINV2095','2006-3-14','AARONFIT0001'),
('ORDST2092','2006-3-12','PLAZAONE0001'),
('STDINV2093','2006-3-12','PLAZAONE0001'),
('ORDST2093','2006-3-13','VANCOUVE0001'),
('STDINV2091','2006-3-11','BLUEYOND0001'),
('ORDST2091','2006-3-11','ASTORSUI0001'),
('STDINV2092','2006-3-11','ASTORSUI0001'),
('ORDST2089','2006-3-11','LAWRENCE0001'),
('STDINV2090','2006-3-11','LAWRENCE0001'),
('ORDST2090','2006-3-11','BLUEYOND0001'),
('STDINV2088','2006-3-9','ASTORSUI0001'),
('ORDST2088','2006-3-10','MAHLERST0001'),
('STDINV2089','2006-3-10','MAHLERST0001'),
('ORDST2086','2006-3-8','METROPOL0001'),
('STDINV2087','2006-3-8','METROPOL0001'),
('ORDST2087','2006-3-9','ASTORSUI0001'),
('STDINV2085','2006-3-6','CENTRALC0001'),
('ORDST2085','2006-3-7','MAGNIFIC0001'),
('STDINV2086','2006-3-7','MAGNIFIC0001'),
('ORDST2083','2006-3-5','PLAZAONE0001'),
('STDINV2084','2006-3-5','PLAZAONE0001'),
('ORDST2084','2006-3-6','CENTRALC0001'),
('STDINV2082','2006-3-4','AARONFIT0001'),
('ORDST2082','2006-3-4','AARONFIT0001'),
('STDINV2083','2006-3-4','AARONFIT0001'),
('ORDST2080','2006-3-4','VANCOUVE0001'),
('STDINV2081','2006-3-4','VANCOUVE0001'),
('ORDST2081','2006-3-4','AARONFIT0001'),
('STDINV2079','2006-3-3','ASTORSUI0001'),
('ORDST2079','2006-3-4','PLAZAONE0001'),
('STDINV2080','2006-3-4','PLAZAONE0001'),
('ORDST2077','2006-3-3','BLUEYOND0001'),
('STDINV2078','2006-3-3','BLUEYOND0001'),
('ORDST2078','2006-3-3','ASTORSUI0001'),
('STDINV2076','2006-3-2','MAHLERST0001'),
('ORDST2076','2006-3-2','LAWRENCE0001'),
('STDINV2077','2006-3-2','LAWRENCE0001'),
('ORDST2074','2006-3-1','METROPOL0001'),
('STDINV2075','2006-3-1','METROPOL0001'),
('ORDST2075','2006-3-2','MAHLERST0001'),
('STDINV2073','2006-2-28','CENTRALC0001'),
('ORDST2073','2006-2-28','MAGNIFIC0001'),
('STDINV2074','2006-2-28','MAGNIFIC0001'),
('ORDST2071','2006-2-27','PLAZAONE0001'),
('STDINV2072','2006-2-27','PLAZAONE0001'),
('ORDST2072','2006-2-28','CENTRALC0001'),
('STDINV2070','2006-2-25','CONTOSOL0001'),
('ORDST2070','2006-2-26','VANCOUVE0001'),
('STDINV2071','2006-2-26','VANCOUVE0001'),
('ORDST2068','2006-2-25','AARONFIT0001'),
('STDINV2069','2006-2-25','AARONFIT0001'),
('ORDST2069','2006-2-25','CONTOSOL0001'),
('STDINV2067','2006-2-23','BREAKTHR0001'),
('ORDST2067','2006-2-24','HOLLINGC0001'),
('STDINV2068','2006-2-24','HOLLINGC0001'),
('ORDST2065','2006-2-23','HOLLINGC0001'),
('STDINV2066','2006-2-23','HOLLINGC0001'),
('ORDST2066','2006-2-23','BREAKTHR0001'),
('STDINV2064','2006-2-22','ASTORSUI0001'),
('ORDST2064','2006-2-22','PLAZAONE0001'),
('STDINV2065','2006-2-22','PLAZAONE0001'),
('ORDST2061','2006-2-22','METROPOL0001'),
('STDINV2062','2006-2-22','METROPOL0001'),
('ORDST2063','2006-2-22','ASTORSUI0001'),
('STDINV2060','2006-2-20','CENTRALC0001'),
('ORDST2060','2006-2-21','MAGNIFIC0001'),
('STDINV2061','2006-2-21','MAGNIFIC0001'),
('ORDST2058','2006-2-20','PLAZAONE0001'),
('STDINV2059','2006-2-20','PLAZAONE0001'),
('ORDST2059','2006-2-20','CENTRALC0001'),
('STDINV2057','2006-2-19','AARONFIT0001'),
('ORDST2057','2006-2-19','AARONFIT0001'),
('STDINV2058','2006-2-19','AARONFIT0001'),
('ORDST2055','2006-2-18','VANCOUVE0001'),
('STDINV2056','2006-2-18','VANCOUVE0001'),
('ORDST2056','2006-2-19','AARONFIT0001'),
('STDINV2054','2006-2-17','ASTORSUI0001'),
('ORDST2054','2006-2-18','PLAZAONE0001'),
('STDINV2055','2006-2-18','PLAZAONE0001'),
('ORDST2052','2006-2-17','BLUEYOND0001'),
('STDINV2053','2006-2-17','BLUEYOND0001'),
('ORDST2053','2006-2-17','ASTORSUI0001'),
('STDINV2051','2006-2-15','MAHLERST0001'),
('ORDST2051','2006-2-16','LAWRENCE0001'),
('STDINV2052','2006-2-16','LAWRENCE0001'),
('ORDST2049','2006-2-14','METROPOL0001'),
('STDINV2050','2006-2-14','METROPOL0001'),
('ORDST2050','2006-2-15','MAHLERST0001'),
('STDINV2048','2006-2-10','CENTRALC0001'),
('ORDST2048','2006-2-11','MAGNIFIC0001'),
('STDINV2049','2006-2-11','MAGNIFIC0001'),
('ORDST2043','2006-2-7','AARONFIT0001'),
('STDINV2044','2006-2-7','AARONFIT0001'),
('ORDST2044','2006-2-8','CONTOSOL0001'),
('STDINV2042','2006-2-5','PLAZAONE0001'),
('ORDST2042','2006-2-6','VANCOUVE0001'),
('STDINV2043','2006-2-6','VANCOUVE0001'),
('ORDST2040','2006-2-4','ASTORSUI0001'),
('STDINV2041','2006-2-4','ASTORSUI0001'),
('ORDST2041','2006-2-5','PLAZAONE0001'),
('STDINV2039','2006-2-3','LAWRENCE0001'),
('ORDST2039','2006-2-3','BLUEYOND0001'),
('STDINV2040','2006-2-3','BLUEYOND0001'),
('STDINV2037','2006-3-4','MAHLERST0001'),
('ORDST2037','2006-2-3','MAHLERST0001'),
('STDINV2038','2006-2-3','MAHLERST0001'),
('ORDST2036','2006-2-2','METROPOL0001'),
('STDINV2036','2006-2-2','METROPOL0001'),
('ORDST2038','2006-2-3','LAWRENCE0001'),
('STDINV2034','2006-1-31','CENTRALC0001'),
('ORDST2035','2006-2-1','MAGNIFIC0001'),
('STDINV2035','2006-2-1','MAGNIFIC0001'),
('ORDST2033','2006-1-30','PLAZAONE0001'),
('STDINV2033','2006-1-30','PLAZAONE0001'),
('ORDST2034','2006-1-31','CENTRALC0001'),
('ORDST2046','2006-2-9','PLAZAONE0001'),
('STDINV2047','2006-2-9','PLAZAONE0001'),
('ORDST2047','2006-2-10','CENTRALC0001'),
('STDINV2045','2006-2-8','CONTOSOL0001'),
('ORDST2045','2006-2-9','VANCOUVE0001'),
('STDINV2046','2006-2-9','VANCOUVE0001'),
('STDINV2031','2006-1-28','CONTOSOL0001'),
('ORDST2032','2006-1-29','VANCOUVE0001'),
('STDINV2032','2006-1-29','VANCOUVE0001'),
('ORDST2030','2006-1-27','AARONFIT0001'),
('STDINV2030','2006-1-27','AARONFIT0001'),
('ORDST2031','2006-1-28','CONTOSOL0001'),
('STDINV2028','2006-1-25','ADAMPARK0001'),
('ORDST2029','2006-1-26','AARONFIT0001'),
('STDINV2029','2006-1-26','AARONFIT0001'),
('ORDST2027','2006-1-24','AARONFIT0001'),
('STDINV2027','2006-1-24','AARONFIT0001'),
('ORDST2028','2006-1-25','ADAMPARK0001'),
('STDINV2025','2006-1-22','VANCOUVE0001'),
('ORDST2026','2006-1-23','AARONFIT0001'),
('STDINV2026','2006-1-23','AARONFIT0001'),
('ORDST2024','2006-1-21','PLAZAONE0001'),
('STDINV2024','2006-1-21','PLAZAONE0001'),
('ORDST2025','2006-1-22','VANCOUVE0001'),
('ORDST2129','2007-1-8','AARONFIT0001'),
('STDINV2130','2007-1-8','AARONFIT0001'),
('ORDST2130','2007-1-8','AARONFIT0001'),
('STDINV2128','2007-1-7','MIDLANDC0001'),
('ORDST2128','2007-1-7','AARONFIT0001'),
('STDINV2129','2007-1-7','AARONFIT0001'),
('ORDST2126','2007-1-6','LONDONBE0001'),
('STDINV2127','2007-1-6','LONDONBE0001'),
('ORDST2127','2007-1-7','MIDLANDC0001'),
('STDINV2124','2007-1-5','AARONFIT0001'),
('ORDST2125','2007-1-6','PLAZAONE0001'),
('STDINV2126','2007-1-6','PLAZAONE0001'),
('ORDST2122','2007-1-5','AARONFIT0001'),
('STDINV2123','2007-1-5','AARONFIT0001'),
('ORDST2123','2007-1-5','AARONFIT0001'),
('STDINV2121','2007-1-3','ADVANCED0001'),
('ORDST2121','2007-1-4','RIVERSID0001'),
('STDINV2122','2007-1-4','RIVERSID0001'),
('ORDST2119','2007-1-3','AARONFIT0001'),
('ORDST2120','2007-1-3','ADVANCED0001'),
('STDINV2120','2007-1-3','AARONFIT0001'),
('STDINV2118','2007-1-1','CONTOSOL0001'),
('ORDST2118','2007-1-2','AMERICAN0001'),
('STDINV2119','2007-1-2','AMERICAN0001'),
('QTEST1009','2004-5-15','CONTOSOL0001'),
('QTEST1019','2004-7-8','CASTLEIN0001'),
('QTEST1020','2004-7-8','ADVANCED0002'),
('QTEST1006','2004-5-9','BOYLESCO0001'),
('QTEST1007','2004-5-11','CENTRALC0001'),
('QTEST1008','2004-5-11','BREAKTHR0001'),
('STDINV2022','2006-1-18','BLUEYOND0001'),
('ORDST2023','2006-1-19','ASTORSUI0001'),
('STDINV2023','2006-1-19','ASTORSUI0001'),
('ORDST2021','2006-1-17','LAWRENCE0001'),
('STDINV2021','2006-1-17','LAWRENCE0001'),
('ORDST2022','2006-1-18','BLUEYOND0001'),
('STDINV2019','2006-1-15','METROPOL0001'),
('ORDST2020','2006-1-16','MAHLERST0001'),
('STDINV2020','2006-1-16','MAHLERST0001'),
('ORDST2018','2006-1-14','MAGNIFIC0001'),
('STDINV2018','2006-1-14','MAGNIFIC0001'),
('ORDST2019','2006-1-15','METROPOL0001'),
('STDINV2016','2006-1-12','PLAZAONE0001'),
('ORDST2017','2006-1-13','CENTRALC0001'),
('STDINV2017','2006-1-13','CENTRALC0001'),
('ORDST2015','2006-1-11','VANCOUVE0001'),
('STDINV2015','2006-1-11','VANCOUVE0001'),
('ORDST2016','2006-1-12','PLAZAONE0001'),
('STDINV2013','2006-1-9','ISNINDUS0001'),
('ORDST2014','2006-1-10','CONTOSOL0001'),
('STDINV2014','2006-1-10','CONTOSOL0001'),
('ORDST2012','2006-1-8','AARONFIT0001'),
('STDINV2012','2006-1-8','AARONFIT0001'),
('ORDST2013','2006-1-9','ISNINDUS0001'),
('STDINV2010','2006-1-7','AARONFIT0001'),
('ORDST2011','2006-1-8','AARONFIT0001'),
('STDINV2011','2006-1-8','AARONFIT0001'),
('ORDST2009','2006-1-7','MIDLANDC0001'),
('STDINV2009','2006-1-7','MIDLANDC0001'),
('ORDST2010','2006-1-7','AARONFIT0001'),
('STDINV2007','2006-1-6','PLAZAONE0001'),
('ORDST2008','2006-1-6','LONDONBE0001'),
('STDINV2008','2006-1-6','LONDONBE0001'),
('ORDST2006','2006-1-5','AARONFIT0001'),
('STDINV2006','2006-1-5','AARONFIT0001'),
('ORDST2007','2006-1-6','PLAZAONE0001'),
('STDINV2004','2006-1-4','RIVERSID0001'),
('ORDST2005','2006-1-5','AARONFIT0001'),
('INVPS1003','2004-5-10','HOLLINGC0001'),
('INV1018','2004-5-10','LAWRENCE0001'),
('INV1019','2004-5-10','BLUEYOND0001'),
('INV1023','2004-5-30','VANCOUVE0001'),
('INV1015','2004-5-10','MAGNIFIC0001'),
('INV1014','2004-5-10','CENTRALC0001'),
('INV1017','2004-5-10','MAHLERST0001'),
('STDINV2005','2006-1-5','AARONFIT0001'),
('ORDST2003','2006-1-3','ADVANCED0001'),
('STDINV2003','2006-1-3','ADVANCED0001'),
('ORDST2004','2006-1-4','RIVERSID0001'),
('STDINV2001','2006-1-2','AMERICAN0001'),
('ORDST2002','2006-1-3','AARONFIT0001'),
('STDINV2002','2006-1-3','AARONFIT0001'),
('ORDST2000','2006-1-1','CONTOSOL0001'),
('STDINV2000','2006-1-1','CONTOSOL0001'),
('ORDST2001','2006-1-2','AMERICAN0001'),
('QTE1002','2004-5-6','ASTORSUI0001'),
('QTERP1000','2004-5-14','BAKERSEM0001'),
('QTEST1005','2004-5-6','LECLERC0001'),
('ORDST1009','2004-5-11','LAWRENCE0001'),
('ORDST1010','2004-5-13','BLUEYOND0001')
]

Cursor.executemany(sql_InvoiceHeader, val)
dbcon.commit()
print(Cursor.rowcount, "Records inserted")
# Out:
# 562 Records inserted

# %%
myquery="select * from InvoiceHeader limit 10"
Cursor.execute(myquery)
myresult = Cursor.fetchall()
for x in myresult:
    print(x)
# Out:
# ('BKO1001', datetime.date(2004, 5, 10), 'CONTOSOL0001')
# ('BKO1003', datetime.date(2005, 5, 8), 'AMERICAN0001')
# ('INV1010', datetime.date(2004, 5, 17), 'ISNINDUS0001')
# ('INV1011', datetime.date(2004, 5, 19), 'MENDOTAU0001')
# ('INV1012', datetime.date(2004, 5, 27), 'KELLYCON0001')
# ('INV1013', datetime.date(2004, 5, 27), 'ADVANCED0002')
# ('INV1014', datetime.date(2004, 5, 10), 'CENTRALC0001')
# ('INV1015', datetime.date(2004, 5, 10), 'MAGNIFIC0001')
# ('INV1016', datetime.date(2004, 5, 10), 'METROPOL0001')
# ('INV1017', datetime.date(2004, 5, 10), 'MAHLERST0001')

# %%
sql_InvoiceDetails="Insert into InvoiceDetails (InvoiceNumber,Quantity,UnitCost,UnitPrice) values (%s,%s,%s,%s)"

# %%
# Insert of multiple records to the table
val=[
    ('ORDST1022',1,59.29,119.95),
    ('ORDST1015',1,3290.55,6589.95),
    ('ORDST1016',10,35,34.95),
    ('ORDST1017',50,91.59,189.95),
    ('ORDST1018',1,59.29,119.95),
    ('INV1010',1,674.5,1349.95),
    ('INV1011',1,91.25,189.95),
    ('INV1012',1,303.85,609.95),
    ('ORDST1020',1,59.29,119.95),
    ('ORDST1021',1,59.29,119.95),
    ('INV1015',1,179.85,359.95),
    ('INV1016',1,3.29,9.95),
    ('INV1017',1,2998.15,5999.95),
    ('BKO1001',1,34550,69109.95),
    ('BKO1003',10,41.98,89.95),
    ('INV1020',3,4.55,9.95),
    ('INV1022',4,93.55,189.95),
    ('INV1023',10,1197,2399.95),
    ('INV1013',5,93.55,189.95),
    ('INV1014',3,3.29,9.95),
    ('INVPS1001',1,92.59,189.95),
    ('INVPS1002',4,4.55,9.95),
    ('INVPS1003',2,27.98,59.95),
    ('INV1018',25,0.16,0.35),
    ('INV1019',1,674.5,1349.95),
    ('INVPS1005',1,303.85,609.95),
    ('INVPS1006',1,50.25,109.95),
    ('INVPS1007',5,9.81,19.95),
    ('INV1024',1,59.29,119.95),
    ('INV1025',1,50.25,109.95),
    ('INVSP1002',1,5.98,19.95),
    ('INVSP1003',1,59.29,119.95),
    ('INVSP1004',2,18.65,39.95),
    ('INVPS1004',2,93.55,189.95),
    ('INVPS1004',1,395.1,854.5),
    ('ORD1002',1,3.29,9.95),
    ('ORD1003',1,35000,70009.95),
    ('ORD1004',1,34550,69109.95),
    ('INVSP1000',4,93.55,189.95),
    ('INVSP1001',1,50.25,109.95),
    ('STDINV2263000',1,4.55,9.95),
    ('STDINV2262000',1,40.5,49.95),
    ('STDINV2262000',1,49.5,49.95),
    ('STDINV2265002',100,184.5,189.95),
    ('STDINV2265000',100,184.5,189.95),
    ('STDINV2264000',100,224.1,224.99),
    ('STDINV2264000',15,238.5,239.95),
    ('STDINV2263000',10,238.5,239.95),
    ('STDINV2263003',10,238.5,239.95),
    ('STDINV2263003',1,4.55,9.95),
    ('STDINV2264003',100,224.1,224.99),
    ('STDINV2264003',15,238.5,239.95),
    ('STDINV2265003',100,184.5,189.95),
    ('STDINV2263001',1,4.55,9.95),
    ('STDINV2262001',1,40.5,49.95),
    ('STDINV2262001',1,49.5,49.95),
    ('STDINV2262003',1,40.5,49.95),
    ('STDINV2262003',1,49.5,49.95),
    ('STDINV2265005',100,184.5,189.95),
    ('STDINV2265001',100,184.5,189.95),
    ('STDINV2264001',100,224.1,224.99),
    ('STDINV2264001',15,238.5,239.95),
    ('STDINV2263001',10,238.5,239.95),
    ('STDINV2262005',1,49.5,49.95),
    ('STDINV2263005',10,238.5,239.95),
    ('STDINV2263005',1,4.55,9.95),
    ('STDINV2264005',100,224.1,224.99),
    ('STDINV2264005',15,238.5,239.95),
    ('STDINV2263',1,4.55,9.95),
    ('STDINV2264',100,224.1,224.99),
    ('STDINV2264',15,238.5,239.95),
    ('STDINV2265',100,184.5,189.95),
    ('STDINV2262005',1,40.5,49.95),
    ('ORDST1023',1,5.98,19.95),
    ('ORDST1023',3,41.98,89.95),
    ('STDINV2262',1,40.5,49.95),
    ('STDINV2262',1,49.5,49.95),
    ('STDINV2263',10,238.5,239.95),
    ('ORDST1019',2,38.59,79.95),
    ('ORDST1019',1,41.98,89.95),
    ('ORDST1018',4,4.55,9.95),
    ('ORDST1012',2,89,179.95),
    ('ORDST1013',1,50.25,109.95),
    ('ORDST1013',9,4.55,9.95),
    ('ORDST1014',1,91.59,189.95),
    ('ORDST1014',1,149.95,295.65),
    ('ORDST1002',1,303.85,609.95),
    ('ORDST1008',1,2998.15,5999.95),
    ('ORDST1009',25,0.16,0.35),
    ('ORDST1010',1,674.5,1349.95),
    ('ORDST1011',2,115.85,239.95),
    ('ORDPH1007',1,50.25,109.95),
    ('ORDRP1000',1,18.65,39.95),
    ('ORDSPEC1000',1,59.29,119.95),
    ('ORDSPEC1001',2,18.65,39.95),
    ('ORDST1002',1,18.65,39.95),
    ('ORDPH1003',100,0.54,0),
    ('ORDPH1003',80,35,0),
    ('ORDPH1004',1,18.65,39.95),
    ('ORDPH1005',2,93.55,189.95),
    ('ORDPH1006',1,303.85,609.95),
    ('ORDPH1002',5,9.81,19.95),
    ('ORDPH1003',1,35.89,79.95),
    ('ORDPH1003',1,5072.3,10149.95),
    ('ORDPH1003',10,41.98,0),
    ('ORDPH1003',10,179.85,0),
    ('ORDST2030',2,55.5,59.95),
    ('ORDST2031',5,55.5,59.95),
    ('ORD1008',1,50.25,109.95),
    ('ORD1009',1,1197,2399.95),
    ('ORDPH1001',1,34550,69109.95),
    ('ORDST2025',10,1197,2399.95),
    ('ORDST2026',1,59.29,119.95),
    ('ORDST2027',1,50.25,109.95),
    ('ORDST2028',10,55.5,59.95),
    ('ORDST2029',10,55.5,59.95),
    ('ORDST2020',2,2998.15,5999.95),
    ('ORDST2021',1,2998.15,5999.95),
    ('ORDST2022',1,674.5,1349.95),
    ('ORDST2023',3,4.55,9.95),
    ('ORDST2024',4,93.55,189.95),
    ('ORDST2015',1,303.85,609.95),
    ('ORDST2016',5,93.55,189.95),
    ('ORDST2017',3,3.29,9.95),
    ('ORDST2018',2,179.85,359.95),
    ('ORDST2019',3,3.29,9.95),
    ('ORDST2010',2,93.55,189.95),
    ('ORDST2011',5,3.29,9.95),
    ('ORDST2012',5,4.55,9.95),
    ('ORDST2013',1,674.5,1349.95),
    ('ORDST2014',1,92.59,189.95),
    ('ORDST2005',1,479.05,959.95),
    ('ORDST2006',5,35.89,79.95),
    ('ORDST2007',2,75.15,149.95),
    ('ORDST2008',3,59.5,119.95),
    ('ORDST2009',2,5.98,19.95),
    ('ORDST2000',5,303.85,609.95),
    ('ORDST2001',6,93.55,189.95),
    ('ORDST2002',6,92.59,189.95),
    ('ORDST2003',4,27.98,119.95),
    ('ORDST2004',2,92.59,189.95),
    ('ORDST1025',4,0,9.95),
    ('ORDST1025',5,879.05,1759.95),
    ('ORDST1026',3,879.05,1759.95),
    ('ORDST1026',5,4.55,9.95),
    ('ORDST1026',2,38.59,79.95),
    ('ORDST2071',3,92.59,189.95),
    ('ORDST2072',6,91.59,189.95),
    ('ORDST1024',3,4.55,9.95),
    ('ORDST1024',1,41.98,89.95),
    ('ORDST1025',1,5.98,19.95),
    ('ORDST2066',2,4.55,9.95),
    ('ORDST2067',4,27.98,59.95),
    ('ORDST2068',2,93.55,189.95),
    ('ORDST2069',1,303.85,609.95),
    ('ORDST2070',1,50.25,109.95),
    ('ORDST2060',4,55.5,59.95),
    ('ORDST2061',1,55.5,59.95),
    ('ORDST2063',1,669,1339.95),
    ('ORDST2064',5.5,0,34.95),
    ('ORDST2065',1,92.59,189.95),
    ('ORDST2055',2,38.59,79.95),
    ('ORDST2056',1,1197,2399.95),
    ('ORDST2057',4,38.59,79.95),
    ('ORDST2058',1,1197,2399.95),
    ('ORDST2059',1,1197,2399.95),
    ('ORDST2050',1,1197,2399.95),
    ('ORDST2051',2,1197,2399.95),
    ('ORDST2052',1,1197,2399.95),
    ('ORDST2053',1,3.29,9.95),
    ('ORDST2054',1,1197,2399.95),
    ('ORDST2045',2,1197,2399.95),
    ('ORDST2046',1,1197,2399.95),
    ('ORDST2047',2,1197,2399.95),
    ('ORDST2048',2,1197,2399.95),
    ('ORDST2049',1,1197,2399.95),
    ('ORDST2040',1,3.29,9.95),
    ('ORDST2041',1,3.29,9.95),
    ('ORDST2042',2,55.5,59.95),
    ('ORDST2043',5,55.5,59.95),
    ('ORDST2044',1,59.29,119.95),
    ('ORDST2035',10,55.5,59.95),
    ('ORDST2036',5,3.29,9.95),
    ('ORDST2037',2,3.29,9.95),
    ('ORDST2038',1,3.29,9.95),
    ('ORDST2039',2,3.29,9.95),
    ('ORDST2111',1,92.59,189.95),
    ('ORDST2112',4,4.55,9.95),
    ('ORDST2032',1,55.5,59.95),
    ('ORDST2033',2,59.29,119.95),
    ('ORDST2034',5,55.5,59.95),
    ('ORDST2106',2,1197,2399.95),
    ('ORDST2107',1,55.5,59.95),
    ('ORDST2108',8,55.5,59.95),
    ('ORDST2109',1,669,1339.95),
    ('ORDST2110',12,0,34.95),
    ('ORDST2101',6,669,1339.95),
    ('ORDST2102',3,38.59,79.95),
    ('ORDST2103',9,1197,2399.95),
    ('ORDST2104',10,38.59,79.95),
    ('ORDST2105',12,1197,2399.95),
    ('ORDST2096',4,3.29,9.95),
    ('ORDST2097',2,59.5,119.95),
    ('ORDST2098',10,50.25,109.95),
    ('ORDST2099',4,18.65,39.95),
    ('ORDST2100',2,5.98,19.95),
    ('ORDST2091',1,59.5,119.95),
    ('ORDST2092',4,6921.88,13849.95),
    ('ORDST2093',3,50.25,109.95),
    ('ORDST2094',12,4.55,9.95),
    ('ORDST2095',36,4.55,9.95),
    ('ORDST2086',3,90.25,189.95),
    ('ORDST2087',3,6921.88,13849.95),
    ('ORDST2088',4,91.59,189.95),
    ('ORDST2089',3,90.25,189.95),
    ('ORDST2090',2,479.05,959.95),
    ('ORDST2081',2,59.5,119.95),
    ('ORDST2082',2,50.25,109.95),
    ('ORDST2083',4,18.65,39.95),
    ('ORDST2084',1,5.98,19.95),
    ('ORDST2085',2,669,1339.95),
    ('ORDST2076',2,6921.88,13849.95),
    ('ORDST2077',1,50.25,109.95),
    ('ORDST2078',5,4.55,9.95),
    ('ORDST2079',3,4.55,9.95),
    ('ORDST2080',2,3.29,9.95),
    ('ORDST2152',1,59.29,119.95),
    ('ORDST2153',1,1400,2809.95),
    ('ORDST2073',4,90.25,189.95),
    ('ORDST2074',2,479.05,959.95),
    ('ORDST2075',3,59.5,119.95),
    ('ORDST2147',2,3.29,9.95),
    ('ORDST2148',1,3.29,9.95),
    ('ORDST2149',2,3.29,9.95),
    ('ORDST2150',1,3.29,9.95),
    ('ORDST2151',1,3.29,9.95),
    ('ORDST2142',10,1400,2809.95),
    ('ORDST2143',1,59.29,119.95),
    ('ORDST2144',1,50.25,109.95),
    ('ORDST2145',2,59.29,119.95),
    ('ORDST2146',5,3.29,9.95),
    ('ORDST2137',2,2998.15,5999.95),
    ('ORDST2138',1,3463.73,6929.95),
    ('ORDST2139',1,674.5,1349.95),
    ('ORDST2140',3,4.55,9.95),
    ('ORDST2141',4,93.55,189.95),
    ('ORDST2132',1,303.85,609.95),
    ('ORDST2133',5,93.55,189.95),
    ('ORDST2134',3,3.29,9.95),
    ('ORDST2135',2,179.85,359.95),
    ('ORDST2136',3,3.29,9.95),
    ('ORDST2127',2,5.98,19.95),
    ('ORDST2128',2,93.55,189.95),
    ('ORDST2129',5,3.29,9.95),
    ('ORDST2130',5,4.55,9.95),
    ('ORDST2131',1,92.59,189.95),
    ('ORDST2121',2,92.59,189.95),
    ('ORDST2122',1,479.05,959.95),
    ('ORDST2123',5,35.89,79.95),
    ('ORDST2125',2,75.15,159.95),
    ('ORDST2126',3,59.5,119.95),
    ('ORDST2116',1,50.25,109.95),
    ('ORDST2117',5,303.85,609.95),
    ('ORDST2118',6,90.25,189.95),
    ('ORDST2119',6,92.59,189.95),
    ('ORDST2120',4,27.98,59.95),
    ('ORDST2191',2,669,1339.95),
    ('ORDST2192',3,90.25,189.95),
    ('ORDST2113',6,27.98,59.95),
    ('ORDST2114',3,90.25,189.95),
    ('ORDST2115',2,303.85,609.95),
    ('ORDST2186',2,3.29,9.95),
    ('ORDST2187',2,59.5,119.95),
    ('ORDST2188',2,50.25,109.95),
    ('ORDST2189',4,18.65,39.95),
    ('ORDST2190',1,5.98,19.95),
    ('ORDST2181',3,59.5,119.95),
    ('ORDST2182',2,6921.88,13849.95),
    ('ORDST2183',1,50.25,109.95),
    ('ORDST2184',5,4.55,9.95),
    ('ORDST2185',3,4.55,9.95),
    ('ORDST2176',1,50.25,109.95),
    ('ORDST2177',3,92.59,189.95),
    ('ORDST2178',6,91.59,189.95),
    ('ORDST2179',4,90.25,189.95),
    ('ORDST2180',2,479.05,959.95),
    ('ORDST2171',1,92.59,189.95),
    ('ORDST2172',2,4.55,9.95),
    ('ORDST2173',4,27.98,59.95),
    ('ORDST2174',2,93.55,189.95),
    ('ORDST2175',1,303.85,609.95),
    ('ORDST2166',1,1197,2399.95),
    ('ORDST2167',4,55.5,59.95),
    ('ORDST2168',1,55.5,59.95),
    ('ORDST2169',1,669,1339.95),
    ('ORDST2170',5.5,0,34.95),
    ('ORDST2162',1,1197,2399.95),
    ('ORDST2163',2,38.59,79.95),
    ('ORDST2164',4,38.59,79.95),
    ('ORDST2164',1,1197,2399.95),
    ('ORDST2165',1,1197,2399.95),
    ('ORDST2157',1,1197,2399.95),
    ('ORDST2158',1,1197,2399.95),
    ('ORDST2159',2,1197,2399.95),
    ('ORDST2160',1,1197,2399.95),
    ('ORDST2161',1,3.29,9.95),
    ('QTEST1019',1,59.29,119.95),
    ('QTEST1020',1,5.98,19.95),
    ('ORDST2154',1,1400,2809.95),
    ('ORDST2155',2,1400,2809.95),
    ('ORDST2156',2,1400,2809.95),
    ('QTEST1006',1,303.85,609.95),
    ('QTEST1007',3,3.29,9.95),
    ('QTEST1008',4,4.55,9.95),
    ('QTEST1009',1,50.25,109.95),
    ('QTEST1017',5,67.55,139.95),
    ('ORDST2221',2,303.85,609.95),
    ('ORDST2222',1,50.25,109.95),
    ('QTE1002',3,4.55,9.95),
    ('QTERP1000',10,35,34.95),
    ('QTEST1005',2,93.55,189.95),
    ('ORDST2216',12,0,34.95),
    ('ORDST2217',1,92.59,189.95),
    ('ORDST2218',4,4.55,9.95),
    ('ORDST2219',6,27.98,59.95),
    ('ORDST2220',3,93.55,189.95),
    ('ORDST2211',12,1197,2399.95),
    ('ORDST2212',2,1197,2399.95),
    ('ORDST2213',1,55.5,59.95),
    ('ORDST2214',8,55.5,59.95),
    ('ORDST2215',1,669,1339.95),
    ('ORDST2206',2,5.98,19.95),
    ('ORDST2207',6,669,1339.95),
    ('ORDST2208',3,38.59,79.95),
    ('ORDST2209',9,1197,2399.95),
    ('ORDST2210',10,38.59,79.95),
    ('ORDST2201',36,4.55,9.95),
    ('ORDST2202',4,3.29,9.95),
    ('ORDST2203',2,59.5,119.95),
    ('ORDST2204',10,50.25,109.95),
    ('ORDST2205',4,18.65,39.95),
    ('ORDST2196',2,479.05,959.95),
    ('ORDST2197',1,59.5,119.95),
    ('ORDST2198',4,6921.88,13849.95),
    ('ORDST2199',3,50.25,109.95),
    ('ORDST2200',12,4.55,9.95),
    ('STDINV2037',2,3.29,9.95),
    ('STDINV2038',2,3.29,9.95),
    ('ORDST2193',3,6921.88,13849.95),
    ('ORDST2194',4,91.59,189.95),
    ('ORDST2195',3,90.25,189.95),
    ('STDINV2032',1,55.5,59.95),
    ('STDINV2033',2,59.29,119.95),
    ('STDINV2034',5,55.5,59.95),
    ('STDINV2035',10,55.5,59.95),
    ('STDINV2036',5,3.29,9.95),
    ('STDINV2027',1,50.25,109.95),
    ('STDINV2028',10,55.5,59.95),
    ('STDINV2029',10,55.5,59.95),
    ('STDINV2030',2,55.5,59.95),
    ('STDINV2031',5,55.5,59.95),
    ('STDINV2022',1,674.5,1349.95),
    ('STDINV2023',3,4.55,9.95),
    ('STDINV2024',4,93.55,189.95),
    ('STDINV2025',10,1197,2399.95),
    ('STDINV2026',1,59.29,119.95),
    ('STDINV2017',3,3.29,9.95),
    ('STDINV2018',2,165.85,359.95),
    ('STDINV2019',3,3.29,9.95),
    ('STDINV2020',2,3188.47,5999.95),
    ('STDINV2021',1,2998.15,5999.95),
    ('STDINV2012',5,4.31,9.95),
    ('STDINV2013',1,674.5,1349.95),
    ('STDINV2014',1,92.59,189.95),
    ('STDINV2015',1,301.54,609.95),
    ('STDINV2016',5,93.36,189.95),
    ('STDINV2007',2,75.15,149.95),
    ('STDINV2008',3,29.75,119.95),
    ('STDINV2009',2,5.98,19.95),
    ('STDINV2010',2,93.55,189.95),
    ('STDINV2011',5,3.29,9.95),
    ('STDINV2002',6,92.59,189.95),
    ('STDINV2003',4,27.98,119.95),
    ('STDINV2004',2,92.59,189.95),
    ('STDINV2005',1,479.05,959.95),
    ('STDINV2006',5,34.59,79.95),
    ('STDINV2078',1,50.25,109.95),
    ('STDINV2079',5,4.55,9.95),
    ('QTEST1020',3,41.98,89.95),
    ('STDINV2000',5,301.54,609.95),
    ('STDINV2001',6,92.59,189.95),
    ('STDINV2073',6,91.59,189.95),
    ('STDINV2074',4,91.59,189.95),
    ('STDINV2075',2,479.05,959.95),
    ('STDINV2076',3,27.98,119.95),
    ('STDINV2077',2,6921.88,13849.95),
    ('STDINV2068',4,29.75,59.95),
    ('STDINV2069',2,93.55,189.95),
    ('STDINV2070',1,301.54,609.95),
    ('STDINV2071',1,50.25,109.95),
    ('STDINV2072',3,90.88,189.95),
    ('STDINV2062',1,55.5,59.95),
    ('STDINV2064',1,698.12,1339.95),
    ('STDINV2065',5.5,0,34.95),
    ('STDINV2066',1,92.59,189.95),
    ('STDINV2067',2,4.55,9.95),
    ('STDINV2057',1,1197,2399.95),
    ('STDINV2058',4,38.59,79.95),
    ('STDINV2059',1,1197,2399.95),
    ('STDINV2060',1,1197,2399.95),
    ('STDINV2061',4,55.5,59.95),
    ('STDINV2052',2,664.96,2399.95),
    ('STDINV2053',1,664.96,2399.95),
    ('STDINV2054',1,3.29,9.95),
    ('STDINV2055',1,1197,2399.95),
    ('STDINV2056',2,38.59,79.95),
    ('STDINV2047',1,1197,2399.95),
    ('STDINV2048',2,1197,2399.95),
    ('STDINV2049',2,1197,2399.95),
    ('STDINV2050',1,1197,2399.95),
    ('STDINV2051',1,664.96,2399.95),
    ('STDINV2042',1,3.29,9.95),
    ('STDINV2043',2,55.5,59.95),
    ('STDINV2044',5,55.5,59.95),
    ('STDINV2045',1,59.29,119.95),
    ('STDINV2046',2,1197,2399.95),
    ('STDINV2118',5,303.85,609.95),
    ('STDINV2119',6,92.59,189.95),
    ('STDINV2039',1,3.29,9.95),
    ('STDINV2040',2,3.29,9.95),
    ('STDINV2041',1,3.29,9.95),
    ('STDINV2113',4,4.55,9.95),
    ('STDINV2114',6,28.57,59.95),
    ('STDINV2115',3,92.59,189.95),
    ('STDINV2116',2,303.85,609.95),
    ('STDINV2117',1,50.25,109.95),
    ('STDINV2108',1,55.5,59.95),
    ('STDINV2109',8,55.5,59.95),
    ('STDINV2110',1,669,1339.95),
    ('STDINV2111',12,0,34.95),
    ('STDINV2112',1,92.59,189.95),
    ('STDINV2103',3,38.59,79.95),
    ('STDINV2104',9,1197,2399.95),
    ('STDINV2105',10,38.59,79.95),
    ('STDINV2106',12,1197,2399.95),
    ('STDINV2107',2,1197,2399.95),
    ('STDINV2098',2,27.98,119.95),
    ('STDINV2099',10,50.25,109.95),
    ('STDINV2100',4,20.45,39.95),
    ('STDINV2101',2,5.98,19.95),
    ('STDINV2102',6,656.77,1339.95),
    ('STDINV2093',4,6921.88,13849.95),
    ('STDINV2094',3,50.25,109.95),
    ('STDINV2095',12,4.55,9.95),
    ('STDINV2096',36,4.55,9.95),
    ('STDINV2097',4,3.29,9.95),
    ('STDINV2088',3,6921.88,13849.95),
    ('STDINV2089',4,91.59,189.95),
    ('STDINV2090',3,91.59,189.95),
    ('STDINV2091',2,479.05,959.95),
    ('STDINV2092',1,27.98,119.95),
    ('STDINV2083',2,50.25,109.95),
    ('STDINV2084',4,20.45,39.95),
    ('STDINV2085',1,5.98,19.95),
    ('STDINV2086',2,698.12,1339.95),
    ('STDINV2087',3,91.59,189.95),
    ('STDINV2160',1,1197,2399.95),
    ('STDINV2161',2,1197,2399.95),
    ('STDINV2080',3,4.55,9.95),
    ('STDINV2081',2,3.29,9.95),
    ('STDINV2082',2,27.98,119.95),
    ('STDINV2155',1,1400,2809.95),
    ('STDINV2156',1,1400,2809.95),
    ('STDINV2157',2,1400,2809.95),
    ('STDINV2158',2,1400,2809.95),
    ('STDINV2159',1,1197,2399.95),
    ('STDINV2149',1,3.29,9.95),
    ('STDINV2150',2,3.29,9.95),
    ('STDINV2151',1,3.29,9.95),
    ('STDINV2153',1,3.29,9.95),
    ('STDINV2154',1,59.29,119.95),
    ('STDINV2144',1,59.29,119.95),
    ('STDINV2145',1,50.25,109.95),
    ('STDINV2146',2,59.29,119.95),
    ('STDINV2147',5,3.29,9.95),
    ('STDINV2148',2,3.29,9.95),
    ('STDINV2139',1,3379.25,6929.95),
    ('STDINV2140',1,674.5,1349.95),
    ('STDINV2141',3,4.55,9.95),
    ('STDINV2142',4,93.55,189.95),
    ('STDINV2143',10,1400,2809.95),
    ('STDINV2134',5,93.55,189.95),
    ('STDINV2135',3,3.29,9.95),
    ('STDINV2136',2,165.85,359.95),
    ('STDINV2137',3,3.29,9.95),
    ('STDINV2138',2,2998.15,5999.95),
    ('STDINV2129',2,93.55,189.95),
    ('STDINV2130',5,3.29,9.95),
    ('STDINV2131',5,4.55,9.95),
    ('STDINV2132',1,92.59,189.95),
    ('STDINV2133',1,303.85,609.95),
    ('STDINV2123',1,479.05,959.95),
    ('STDINV2124',5,35.89,79.95),
    ('STDINV2126',2,75.15,159.95),
    ('STDINV2127',3,27.98,119.95),
    ('STDINV2128',2,5.98,19.95),
    ('STDINV2199',1,27.98,119.95),
    ('STDINV2200',4,6921.88,13849.95),
    ('STDINV2120',6,92.59,189.95),
    ('STDINV2121',4,27.98,59.95),
    ('STDINV2122',2,92.59,189.95),
    ('STDINV2194',3,92.25,189.95),
    ('STDINV2195',3,6896.35,13849.95),
    ('STDINV2196',4,92.59,189.95),
    ('STDINV2197',3,90.25,189.95),
    ('STDINV2198',2,479.05,959.95),
    ('STDINV2189',2,59.5,119.95),
    ('STDINV2190',2,50.25,109.95),
    ('STDINV2191',4,20.45,39.95),
    ('STDINV2192',1,5.98,19.95),
    ('STDINV2193',2,669,1339.95),
    ('STDINV2184',2,6883.59,13849.95),
    ('STDINV2185',1,50.25,109.95),
    ('STDINV2186',5,4.55,9.95),
    ('STDINV2187',3,4.55,9.95),
    ('STDINV2188',2,3.29,9.95),
    ('STDINV2179',3,92.59,189.95),
    ('STDINV2180',6,92.59,189.95),
    ('STDINV2181',4,92.01,189.95),
    ('STDINV2182',2,479.05,959.95),
    ('STDINV2183',3,59.5,119.95),
    ('STDINV2174',2,4.55,9.95),
    ('STDINV2175',4,27.98,59.95),
    ('STDINV2176',2,93.55,189.95),
    ('STDINV2177',1,303.85,609.95),
    ('STDINV2178',1,50.25,109.95),
    ('STDINV2169',4,55.5,59.95),
    ('STDINV2170',1,55.5,59.95),
    ('STDINV2171',1,669,1339.95),
    ('STDINV2172',5.5,0,34.95),
    ('STDINV2173',1,92.59,189.95),
    ('STDINV2165',2,38.59,79.95),
    ('STDINV2166',4,38.59,79.95),
    ('STDINV2166',1,1197,2399.95),
    ('STDINV2167',1,1197,2399.95),
    ('STDINV2168',1,2500,2399.95),
    ('STDINV2247',4,4.55,9.95),
    ('STDINV2248',1,34550,69109.95),
    ('STDINV2162',1,1197,2399.95),
    ('STDINV2163',1,3.29,9.95),
    ('STDINV2164',1,1197,2399.95),
    ('STDINV2240',1,20.45,39.95),
    ('STDINV2240',1,303.85,609.95),
    ('STDINV2241',2,115.85,239.95),
    ('STDINV2245',1,3290.55,6589.95),
    ('STDINV2246',3,3.29,9.95),
    ('STDINV2228',1,3.29,9.95),
    ('STDINV2228',1,50.25,109.95),
    ('STDINV2229',1,1197,2399.95),
    ('STDINV2234',5,91.99,189.95),
    ('STDINV2237',1,35000,70009.95),
    ('STDINV2224',1,50.25,109.95),
    ('STDINV2225',1,41.98,89.95),
    ('STDINV2226',1,5.98,19.95),
    ('STDINV2226',3,879.05,1759.95),
    ('STDINV2227',2,25.71,79.95),
    ('STDINV2219',1,92.59,189.95),
    ('STDINV2220',4,4.55,9.95),
    ('STDINV2221',6,27.98,59.95),
    ('STDINV2222',3,93.55,189.95),
    ('STDINV2223',2,303.85,609.95),
    ('STDINV2214',2,1197,2399.95),
    ('STDINV2215',1,55.5,59.95),
    ('STDINV2216',8,55.5,59.95),
    ('STDINV2217',1,669,1339.95),
    ('STDINV2218',12,0,34.95),
    ('STDINV2209',6,669,1339.95),
    ('STDINV2210',3,25.73,79.95),
    ('STDINV2211',9,1631.33,2399.95),
    ('STDINV2212',10,25.73,79.95),
    ('STDINV2213',12,1197,2399.95),
    ('STDINV2204',4,3.29,9.95),
    ('STDINV2205',2,27.98,119.95),
    ('STDINV2206',10,50.25,109.95),
    ('STDINV2207',4,20.45,39.95),
    ('STDINV2208',2,5.98,19.95),
    ('STDINV2253',10,41.98,89.95),
    ('STDINV2254',2,899,1759.95),
    ('STDINV2201',3,50.25,109.95),
    ('STDINV2202',12,4.55,9.95),
    ('STDINV2203',36,4.55,9.95),
    ('STDINV2249',1,34550,69109.95),
    ('STDINV2250',3,4.55,9.95),
    ('STDINV2251',4,75,9.95),
    ('STDINV2252',3,899,1759.95),
    ('STDINV2252',5,4.55,9.95),
    ('ORD1005',1,303.85,609.95),
    ('ORD1005',5,3.29,9.95),
    ('ORD1006',1,3290.55,6589.95),
    ('ORD1007',3,4.55,9.95),
    ('ORD1008',1,3.29,9.95),
    ('ORD1000',1,179.85,359.95),
    ('ORD1001',2,27.98,59.95)
]

Cursor.executemany(sql_InvoiceDetails, val)
dbcon.commit()
print(Cursor.rowcount, "Records inserted")
# Out:
# 603 Records inserted

# %%
myquery="select * from InvoiceDetails limit 10"
Cursor.execute(myquery)
myresult = Cursor.fetchall()
for x in myresult:
    print(x)
# Out:
# ('ORDST1022', 1, 59.29, 119.95)
# ('ORDST1015', 1, 3290.55, 6589.95)
# ('ORDST1016', 10, 35.0, 34.95)
# ('ORDST1017', 50, 91.59, 189.95)
# ('ORDST1018', 1, 59.29, 119.95)
# ('INV1010', 1, 674.5, 1349.95)
# ('INV1011', 1, 91.25, 189.95)
# ('INV1012', 1, 303.85, 609.95)
# ('ORDST1020', 1, 59.29, 119.95)
# ('ORDST1021', 1, 59.29, 119.95)

# %%
dbcon.close()
